# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Data

# %%
data = pd.DataFrame.from_dict ({
    'life': [43,56,49,45,32,26,37,46,41,29],
    'income': [30000,76000,89000,47000,69000,75000,68000,43000,89000,45000],
    'mountain_age':[47,56,57,59,54,23,45,45,63,61],
    'mountain_income': [20000,46000,69000,37000,49000,35000,82000,43000,36000,44000]
})

# %%
res = pd.DataFrame(data)

# %%
plt.boxplot(data.life)
plt.boxplot(data.income)
plt.title("Boxplot of Life & Income")
plt.show()

# %%
plt.title("Mountain Region Data")
plt.boxplot(data.mountain_age)
plt.boxplot(data.mountain_income)
plt.show()
